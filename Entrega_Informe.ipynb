# %% [markdown]
# # Examen final PEIA - Informe
# ## Grupo 5
# * a1612 - Christopher Charaf Herrera
# * a1618 - Myrna Degano
# * a1620 - Gustavo Rivas
#
#
# ## Planteamiento de los problemas de investigación:
# ### a) Analizar el comportamiento de las ventas en cada mes para ambas tiendas.
# ### b) Analizar el comportamiento de las ventas en cada día de la semana para ambas tiendas.
# ### c) Comparar las ventas entre las tiendas 'Santa Ana' y 'La Floresta'.
#
# ## Procesamiento realizado a los datos:
#
# * Se cargaron los datos de ambas tiendas en dataframes de pandas.
# * Se añadieron columnas para mes y día de la semana.
# * Se calcularon las distribuciones empíricas, funciones de densidad e intervalos de confianza para cada mes y día de la semana.
# * Se realizó una prueba de hipótesis (t-test) para comparar las ventas entre ambas tiendas.
#
#
# ## Resultados encontrados:
#
# ### a) Análisis por mes:
#
#  *(Aquí se incluyen gráficos y tablas con los resultados de las distribuciones empíricas, funciones de densidad e intervalos de confianza para cada mes)*
#
#  ### Tienda La Floresta
#
#  <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Ventas</th>
#     </tr>
#     <tr>
#       <th>Fecha</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2023-01</th>
#       <td>518276.809601</td>
#     </tr>
#     <tr>
#       <th>2023-02</th>
#       <td>525269.955847</td>
#     </tr>
#     <tr>
#       <th>2023-03</th>
#       <td>652387.603906</td>
#     </tr>
#     <tr>
#       <th>2023-04</th>
#       <td>599982.260459</td>
#     </tr>
#     <tr>
#       <th>2023-05</th>
#       <td>662528.437527</td>
#     </tr>
#     <tr>
#       <th>2023-06</th>
#       <td>686416.727300</td>
#     </tr>
#     <tr>
#       <th>2023-07</th>
#       <td>635172.453200</td>
#     </tr>
#     <tr>
#       <th>2023-08</th>
#       <td>676583.099018</td>
#     </tr>
#     <tr>
#       <th>2023-09</th>
#       <td>673080.085808</td>
#     </tr>
#     <tr>
#       <th>2023-10</th>
#       <td>680830.785203</td>
#     </tr>
#     <tr>
#       <th>2023-11</th>
#       <td>671415.583088</td>
#     </tr>
#     <tr>
#       <th>2023-12</th>
#       <td>616486.833443</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
#  ![image.png](attachment:image.png)
#
#  Intervalos de confianza La Floresta
#
# <b>La Floresta - Ventas enero (USD)</b>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>15863.27</td>
#       <td>16718.61</td>
#       <td>17870.35</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>15566.87</td>
#       <td>16718.61</td>
#       <td>17870.35</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>La Floresta - Ventas febrero (USD)</b>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>17768.69</td>
#       <td>18759.64</td>
#       <td>20097.76</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>17421.52</td>
#       <td>18759.64</td>
#       <td>20097.76</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>La Floresta - Ventas marzo (USD)</b>
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>20002.89</td>
#       <td>21044.76</td>
#       <td>22447.68</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>19641.85</td>
#       <td>21044.76</td>
#       <td>22447.68</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>La Floresta - Ventas abril (USD)</b>
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>18934.68</td>
#       <td>19999.41</td>
#       <td>21434.36</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>18564.46</td>
#       <td>19999.41</td>
#       <td>21434.36</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>La Floresta - Ventas mayo (USD)</b>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>20355.83</td>
#       <td>21371.89</td>
#       <td>22740.03</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td
td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>Santa Ana - Ventas JUEVES (USD)</b>
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>20155.03</td>
#       <td>20910.55</td>
#       <td>21917.51</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>19903.59</td>
#       <td>20910.55</td>
#       <td>21917.51</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>Santa Ana - Ventas VIERNES (USD)</b>
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>18866.49</td>
#       <td>19589.35</td>
#       <td>20552.78</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>18625.92</td>
#       <td>19589.35</td>
#       <td>20552.78</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>Santa Ana - Ventas SÁBADO (USD)</b>
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>17529.91</td>
#       <td>18183.38</td>
#       <td>19054.33</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>17312.43</td>
#       <td>18183.38</td>
#       <td>19054.33</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
# <b>Santa Ana - Ventas DOMINGO (USD)</b>
#
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Límite inferior</th>
#       <th>Media</th>
#       <th>Límite superior</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>95%</th>
#       <td>15245.30</td>
#       <td>15913.01</td>
#       <td>16802.7</td>
#     </tr>
#     <tr>
#       <th>99%</th>
#       <td>15023.32</td>
#       <td>15913.01</td>
#       <td>16802.7</td>
#     </tr>
#   </tbody>
# </table>
# </div>
#
#
#
#
# ### c) Comparación entre tiendas:
#
# ![comparacion_tiendas.png](attachment:comparacion_tiendas.png)
#
#
#
# ### Las hipótesis planteadas.
#
# * Hipótesis nula (H0): \
# No hay diferencia significativa en las ventas de ambas tiendas. =>
# La media de las ventas diarias de ambas tiendas no es significativamente diferente.
#
# * Hipótesis alternativa (H1): \
# En 'La Floresta' se vende menos que en'Santa Ana' => La media de las ventas diarias de 'La Floresta' es menor que la media de las ventas diarias de 'Santa Ana'.
#
#
#
#
#
# ## Análisis y conclusiones:
#
# ### a) Comportamiento de ventas por mes:
#
# * Para ambas tiendas se observan menores ventas para el mes de **Enero**
#
# * Para la tienda Santa Ana se observa que el mes de mayor venta es **Septiembre**
#
# * Para la tienda La Floresta se observa que el mes de mayor venta es **Noviembre**
#
# ### b) Comportamiento de ventas por día de la semana:
#
# * Para ambas tiendas se observa que el día con menores ventas es el día **Domingo**
# * Para ambas tiendas se onserva que el día con mayores ventas es el día **Jueves**
#
# ### c) Comparación entre tiendas:
# *(Aquí se interpreta el resultado de la prueba t, indicando si hay una diferencia significativa en las ventas entre ambas tiendas)*
#
# **Para significancia del 95%:**
# NO hay evidencia suficiente para concluir que la tienda 'La Floresta' vende menos que la tienda 'Santa Ana'.
#
# **Para significancia del 99%:**
# NO hay evidencia suficiente para concluir que la tienda 'La Floresta' vende menos que la tienda 'Santa Ana'.
#
# ### Recomendaciones para Don Francisco:
#
#
# * Mes recomendado para vacaciones:
# **Enero** *(basado en el mes con menores ventas en ambas tiendas)*
#
# * Mes recomendado para inversiones:
# **Septiembre y Noviembre** *(basado en el meses con mayores ventas para Santa Ana y La Floresta respectivamente)*
#
# #### Ajustes en los horarios de atención y contratación de personal:
#
# * Tanto en La FLoresta como en Santa Ana deberían reducir el personal los días **domingo** que es el día de la semana que de media tienen menores ventas ambas tiendas.
#
# * Tanto en La Floresta como en Santa Ana debería reforzar el personal los día **jueves**  que es el día de la semana que de media tienen mayores ventas ambas tiendas  *(basado en el análisis por día de la semana)*
